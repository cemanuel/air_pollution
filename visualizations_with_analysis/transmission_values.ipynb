# %%
import numpy as np
predicted_values = np.load("_output_predicted_values.npy")
predicted_values.reshape(len(predicted_values), 1)
# Out:
# array([[28.317518 ],
#        [21.621384 ],
#        [26.338186 ],
#        [27.950272 ],
#        [22.796642 ],
#        [30.666254 ],
#        [25.57704  ],
#        [34.428726 ],
#        [32.99418  ],
#        [21.900972 ],
#        [25.886398 ],
#        [19.632933 ],
#        [26.0774   ],
#        [28.3791   ],
#        [24.54684  ],
#        [24.121687 ],
#        [28.64801  ],
#        [28.377174 ],
#        [25.850307 ],
#        [23.771166 ],
#        [19.633724 ],
#        [30.870193 ],
#        [29.355846 ],
#        [27.201504 ],
#        [22.015205 ],
#        [23.513569 ],
#        [25.411343 ],
#        [31.250973 ],
#        [20.566383 ],
#        [22.038845 ],
#        [24.83101  ],
#        [27.635056 ],
#        [25.03392  ],
#        [28.30278  ],
#        [26.804527 ],
#        [24.566628 ],
#        [32.31437  ],
#        [26.836285 ],
#        [27.51373  ],
#        [22.290422 ],
#        [28.047932 ],
#        [23.534325 ],
#        [22.82856  ],
# ...

# %%
new_predicted_values = predicted_values + np.random.logistic(0, 1, len(predicted_values)).reshape(len(predicted_values), 1)
np.save("_new_output_predicted_values", new_predicted_values)

# %%
predicted_values = np.load("_new_output_predicted_values.npy")
predicted_values
# Out:
# array([[27.5079119 ],
#        [21.23342339],
#        [27.86757815],
#        [25.54899819],
#        [24.68434319],
#        [29.89499719],
#        [26.48068085],
#        [35.53262193],
#        [36.18414451],
#        [28.52612824],
#        [25.06829236],
#        [18.69689351],
#        [25.90149202],
#        [31.80644806],
#        [23.54940507],
#        [23.36268576],
#        [27.68529906],
#        [28.83810199],
#        [24.87538154],
#        [27.10709003],
#        [20.55614731],
#        [29.19705379],
#        [27.71895783],
#        [24.29101012],
#        [21.42071345],
#        [23.87081315],
#        [25.61982975],
#        [29.45813807],
#        [20.46130665],
#        [23.88189234],
#        [26.52311137],
#        [26.22373447],
#        [22.12489315],
#        [29.15151873],
#        [21.96061832],
#        [25.74909372],
#        [31.25591559],
#        [25.95034255],
#        [28.06729271],
#        [22.44820407],
#        [27.38367607],
# ...
